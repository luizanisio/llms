# %%
# Visualização dos dados de entrada
import pandas as pd
arq = './dados/pubmed-rct-20k.parquet'
df = pd.read_parquet(arq)
df = df[(df['split'] == 'dev') & (df['split'] == 'dev')]
df[df['pmid'] <= '24252935']
#df[(df['integra'] == '') & (df['fold'] == 12)]
#df

#df
# Out:
#         pmid                                            article split  \
# 0   24219891  Plasminogen activator inhibitor-1, monocyte ch...   dev
# 1   24220044  Training in methods of preventing childhood ob...   dev
# 2   24220504  Golden plaster for pain therapy in patients wi...   dev
# 3   24220704  Reference range for the antimüllerian hormone ...   dev
# 4   24220935  Circulating proteins as potential biomarkers o...   dev
# 5   24225201  Clinical profiles and outcomes in patients wit...   dev
# 6   24225216  [Clinical significance of dynamic monitoring o...   dev
# 7   24225356  Linear growth increased in young children in a...   dev
# 8   24225379  Visual outcome of patients following NAION aft...   dev
# 9   24225740  Effects of antioxidant supplementation on exer...   dev
# 10  24226381  Prophylaxis of intra- and postoperative nausea...   dev
# 11  24226808  High-sensitivity troponin I for risk assessmen...   dev
# 12  24228532  [Multi-centered, randomized controlled clinica...   dev
# 13  24228533  [Randomized controlled study of integrated tre...   dev
# 14  24228534  [Intervention of immune 1 combined HAART on im...   dev
# 15  24228747  The spinal stenosis pedometer and nutrition li...   dev
# 16  24229360  Azithromycin and cough-specific health status ...   dev
# 17  24229362  Study protocol: Rehabilitation including Socia...   dev
# 18  24229754  Efficacy and safety of desvenlafaxine 50 mg/d ...   dev
# 19  24231400  Impact of physical exercise on reaction time i...   dev
# 20  24231627  Docetaxel or pemetrexed with or without cetuxi...   dev
# 21  24231639  Higher protein intake improves length, not wei...   dev
# 22  24232133  Minimally invasive surgery training using mult...   dev
# 23  24232362  A randomized feasibility study of a 12-week co...   dev
# 24  24232445  The impact of missing data on clinical trials:...   dev
# 25  24233244  The effects of aerobic exercise training at tw...   dev
# 26  24236828  Efficacy and safety of low-dose otelixizumab a...   dev
# 27  24237188  Purified dry extract of Paullinia cupana (guar...   dev
# 28  24239154  One-year results of the randomized, controlled...   dev
# 29  24239202  5-year results of a randomized comparison of X...   dev
# 30  24239210  Fluorouracil, epirubicin, and cyclophosphamide...   dev
# 31  24239213  Pharmacist, general practitioner and consumer ...   dev
# 32  24240354  Corneal inflammatory events with daily silicon...   dev
# 33  24240384  Alpha lipoic acid attenuates inflammatory resp...   dev
# 34  24240611  Mechanical chest compressions and simultaneous...   dev
# 35  24241327  An estimate of hernia prevalence in Sierra Leo...   dev
# 36  24245738  Early accelerated senescence of circulating en...   dev
# 37  24245844  Preformulated implementation intentions to pro...   dev
# 38  24245880  Rejuvenation effects of hyaluronic acid inject...   dev
# 39  24246119  [Moderate potentially drug-induced hyponatremi...   dev
# 40  24246588  Effect of an intervention to improve the cardi...   dev
# 41  24247211  Differential effects of FODMAPs (fermentable o...   dev
# 42  24247300  Low-dose dopamine or low-dose nesiritide in ac...   dev
# 43  24247476  The glucoregulatory benefits of glucagon-like ...   dev
# 44  24247812  A pharmacokinetic and pharmacodynamic comparis...   dev
# 45  24248037  A randomized controlled trial to assess adhere...   dev
# 46  24248549  The effect of two different trochanteric nail ...   dev
# 47  24249049  Cardiac structure and function in heart failur...   dev
# 48  24249434  Additive postprandial glucose-lowering effects...   dev
# 49  24249853  A scale to measure pharmacy students' self-eff...   dev
# 50  24251386  Cost-effectiveness of tooth replacement strate...   dev
# 51  24252596  Copenhagen study of overweight patients with c...   dev
# 52  24252663  Comparing in-person to videoconference-based c...   dev
#
#                                              response
# 0   {'background': '', 'conclusions': 'Temporary h...
# 1   {'background': '', 'conclusions': 'Training in...
# 2   {'background': 'Osteoarthritis is a relatively...
# 3   {'background': '', 'conclusions': 'Age-specifi...
# 4   {'background': '', 'conclusions': 'Our finding...
# 5   {'background': 'Heart failure ( HF ) and chron...
# 6   {'background': '', 'conclusions': 'Dynamic mon...
# 7   {'background': 'Haiti has experienced rapid ur...
# 8   {'background': '', 'conclusions': 'This is the...
# 9   {'background': '', 'conclusions': 'Aerobic exe...
# 10  {'background': 'This paper describes a randomi...
# 11  {'background': 'High-sensitivity troponin-I ( ...
# 12  {'background': '', 'conclusions': 'Integrated ...
# 13  {'background': '', 'conclusions': 'The integra...
# 14  {'background': '', 'conclusions': 'Immune 1 co...
# 15  {'background': 'Because of symptoms , people w...
# 16  {'background': 'Macrolides reduce exacerbation...
# 17  {'background': 'During cancer treatment childr...
# 18  {'background': 'ClinicalTrials.gov identifier ...
# 19  {'background': '', 'conclusions': 'Supervised ...
# 20  {'background': 'Available preclinical and phas...
# 21  {'background': '', 'conclusions': 'Higher cumu...
# 22  {'background': 'Structural learning theory sug...
# 23  {'background': '', 'conclusions': 'Observed ef...
# 24  {'background': '', 'conclusions': 'There is no...
# 25  {'background': '', 'conclusions': 'Exercise tr...
# 26  {'background': '', 'conclusions': 'Efficacy an...
# 27  {'background': '', 'conclusions': 'We conclude...
# 28  {'background': 'Previous studies on cognitive ...
# 29  {'background': 'The use of EES compared to PES...
# 30  {'background': 'Neoadjuvant chemotherapy with ...
# 31  {'background': 'Providing written medicine inf...
# 32  {'background': '', 'conclusions': 'The probabi...
# 33  {'background': '', 'conclusions': 'Our finding...
# 34  {'background': 'clinicaltrials.gov Identifier ...
# 35  {'background': '', 'conclusions': 'The results...
# 36  {'background': 'The decreased number and senes...
# 37  {'background': '', 'conclusions': 'Preformulat...
# 38  {'background': 'Pronounced nasojugal groove ( ...
# 39  {'background': '', 'conclusions': 'This study ...
# 40  {'background': 'Family members of patients wit...
# 41  {'background': '', 'conclusions': 'Fructose bu...
# 42  {'background': 'clinicaltrials.gov Identifier ...
# 43  {'background': '', 'conclusions': 'Glucagon-li...
# 44  {'background': 'Previous metoprolol studies in...
# 45  {'background': 'Short message service ( SMS ) ...
# 46  {'background': '', 'conclusions': 'Both design...
# 47  {'background': 'Heart failure with preserved e...
# 48  {'background': 'The aim of this research was t...
# 49  {'background': '', 'conclusions': '', 'journal...
# 50  {'background': '', 'conclusions': 'With an inc...
# 51  {'background': 'Coronary artery disease ( CAD ...
# 52  {'background': 'Cognitive-behavioral therapy (...

# %%
# Visualização dos dados de entrada
import pandas as pd
arq = './saidas/saida_pubmed_prof.parquet'
df = pd.read_parquet(arq)

df
# Out:
#           chave resumo                                           resposta erro
# 0      24219891     {}  {"background": "", "conclusions": "Temporary h...
# 1      24220044     {}  {"background": "", "conclusions": "Training in...
# 2      24220504     {}  {"background": "Osteoarthritis is a relatively...
# 3      24220704     {}  {"background": "", "conclusions": "Age-specifi...
# 4      24220935     {}  {"background": "", "conclusions": "Our finding...
# ...         ...    ...                                                ...  ...
# 19990  26521572     {}  {"background": "", "conclusions": "The simulta...
# 19991  26521581     {}  {"background": "", "conclusions": "Acupuncture...
# 19992  26521582     {}  {"background": "", "conclusions": "The clinica...
# 19993  26521589     {}  {"background": "", "conclusions": "EA at Neigu...
# 19994  26529159     {}  {"background": "clinicaltrials.gov Identifier ...
#
# [19995 rows x 4 columns]

# %%
from util_pubmed import enrich_abstract
enrich_abstract(24228747)
# Out:
# Env encontrado em ../../src/.env
# {'pmid': '24228747',
#  'titulo': 'The spinal stenosis pedometer and nutrition lifestyle intervention (SSPANLI) randomized controlled trial protocol.',
#  'palavras_chave': [],
#  'journal': 'BMC musculoskeletal disorders',
#  'data_publicacao': '2013-Nov'}
