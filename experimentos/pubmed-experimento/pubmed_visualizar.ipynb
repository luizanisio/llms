# %%
# Visualização dos dados de entrada
import pandas as pd
arq = './dados/pubmed-rct-20k.parquet'
df = pd.read_parquet(arq)
df = df[(df['split'] == 'test') ]
df[df['pmid'] <= '24252935']
#df[(df['integra'] == '') & (df['fold'] == 12)]
#df

#df
# Out:
#           pmid                                            article split  \
# 2499  24220007  Comparative effectiveness of 3-dimensional vs ...  test
# 2500  24220099  Results of a randomized controlled trial to pr...  test
# 2501  24220161  The impact of prenatal vitamin A and zinc supp...  test
# 2502  24220547  Adolescent depressive disorders and family bas...  test
# 2503  24220913  Postdiagnosis C-reactive protein and breast ca...  test
# 2504  24222508  The relation between social support and smokin...  test
# 2505  24225010  Spinal manipulative therapy and exercise for s...  test
# 2506  24225081  Porvoo sarcopenia and nutrition trial: effects...  test
# 2507  24225149  Diabetes self-management smartphone applicatio...  test
# 2508  24225780  Photodynamic therapy to treat periimplantitis....  test
# 2509  24226490  Influence of LMA cuff pressure on the incidenc...  test
# 2510  24228683  The impact of school water, sanitation, and hy...  test
# ...

# %%
# Visualização dos dados de entrada
import pandas as pd
arq = './saidas/saida_pubmed_prof.parquet'
df = pd.read_parquet(arq)

df
# Out:
#           chave resumo                                           resposta erro
# 0      24219891     {}  {"background": "", "conclusions": "Temporary h...
# 1      24220044     {}  {"background": "", "conclusions": "Training in...
# 2      24220504     {}  {"background": "Osteoarthritis is a relatively...
# 3      24220704     {}  {"background": "", "conclusions": "Age-specifi...
# 4      24220935     {}  {"background": "", "conclusions": "Our finding...
# ...         ...    ...                                                ...  ...
# 19990  26521572     {}  {"background": "", "conclusions": "The simulta...
# 19991  26521581     {}  {"background": "", "conclusions": "Acupuncture...
# 19992  26521582     {}  {"background": "", "conclusions": "The clinica...
# 19993  26521589     {}  {"background": "", "conclusions": "EA at Neigu...
# 19994  26529159     {}  {"background": "clinicaltrials.gov Identifier ...
#
# [19995 rows x 4 columns]

# %%
# Visualização dos dados de entrada
import pandas as pd
arq = './saidas/saida_pubmed_1_5b(c)_teste.parquet'
df = pd.read_parquet(arq)
df
# Out:
#          chave                                             resumo  \
# 0     24772594  {"prompt_tokens": 614, "completion_tokens": 40...
# 1     24773166  {"prompt_tokens": 805, "completion_tokens": 40...
# 2     24773567  {"prompt_tokens": 712, "completion_tokens": 40...
# 3     24774260  {"prompt_tokens": 642, "completion_tokens": 40...
# 4     24774351  {"prompt_tokens": 615, "completion_tokens": 40...
# ...        ...                                                ...
# 2495  24769399  {"prompt_tokens": 690, "completion_tokens": 40...
# 2496  24769601  {"prompt_tokens": 607, "completion_tokens": 40...
# 2497  24770694  {"prompt_tokens": 677, "completion_tokens": 40...
# 2498  24771706  {"prompt_tokens": 665, "completion_tokens": 40...
# 2499  24772412  {"prompt_tokens": 552, "completion_tokens": 40...
#
#                                                resposta  \
# 0     !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!...
# 1     !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!...
# ...

# %%
from util_pubmed import enrich_abstract
enrich_abstract(24228747)
# Out:
# Env encontrado em ../../src/.env
# {'pmid': '24228747',
#  'titulo': 'The spinal stenosis pedometer and nutrition lifestyle intervention (SSPANLI) randomized controlled trial protocol.',
#  'palavras_chave': [],
#  'journal': 'BMC musculoskeletal disorders',
#  'data_publicacao': '2013-Nov'}
